# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.expedia.co.uk/Hotel-Search?adults=2&children=&destination=United+Kingdom&endDate=2023-09-09&latLong=&mapBounds=&pwaDialog=&regionId=190&rfrrid=TG.LP.Hotels.Hotel&semdtl=&sort=RECOMMENDED&startDate=2023-09-08&theme=&useRewards=false&userIntent="

# %%
res = requests.get(url)
res = res.content

# %%
soup = BeautifulSoup(res, 'html.parser')

# %%
listings = soup.find('div', data_stid='property-listing-results')
listings
# container = soup.find_all('div', class_='uitk-spacing-margin-blockstart-three')
# container_content = container.find_all('div', class_='uitk-card-content-section uitk-card-content-section-padded ')
# container_content

# %%
# Out:
# [<div class="uitk-spacing uitk-spacing-margin-blockstart-three"><fieldset><legend><h4 class="uitk-heading uitk-heading-7">Total price</h4></legend><div class="uitk-spacing uitk-spacing-margin-blockstart-four"><div class="uitk-slider-container uitk-slider-container-disabled" style="--min:0;--max:800;--step:80"><div class="uitk-slider" style="width:100%"><input aria-label="Minimum price" aria-valuemax="800" aria-valuemin="0" aria-valuenow="0" aria-valuetext="£0" class="uitk-slider-input slider-primary" disabled="" id="price-primary" max="800" min="0" name="price" step="80" style="--slider-primary:0%" type="number" value="0"/><label class="is-hidden" for="price-primary">Minimum price</label></div><span aria-hidden="true" class="uitk-slider-output">£0</span><div class="uitk-slider" style="width:100%"><input aria-label="Maximum price" aria-valuemax="800" aria-valuemin="0" aria-valuenow="800" aria-valuetext="£800+" class="uitk-slider-input slider-secondary" disabled="" id="price-secondary"
# ...
